# %% [markdown]
# ## Analizar alpha generado por la señal VIXSI en el activo SPY
#
# Utilizando los datos históricos de la señal VIXSI, se puede analizar el alpha generado por el algoritmo de trading que utiliza la señal VIXSI para mantener comprado (VIXSI=1) o vendido (en corto) (VIXSI=-1) diariamente el activo SPY, donde el benchmark es el propio activo.
#
# En este estudio se ignoran las comisiones.
#
# [alpha VIXSI con SPY](#alpha_vixsi_spy)
#
#
# ## Analizar alpha generado por la señal VIXSI en activos correlacionados con SPY
#
#
# Se seleccionan los 5 activos más correlacionados con el SPY

# %%
#%pip install --upgrade investpy

import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

import yfinance as yf
from bs4 import BeautifulSoup
import requests
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import time

# %%
tickers = pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
# Se seleccionan los activos que se unieron al índice antes del 2014
tickers = tickers[tickers["Date added"]<="2001-01-01"]
tickers = tickers.Symbol.to_list()
tickers.insert(0, 'SPY')

# %%
data = yf.download(tickers, '2008-01-01', '2024-08-25', auto_adjust=True)['Close']
# Print the first few rows of the fetched data
data.head()
# Out:
# [*********************100%***********************]  190 of 190 completed
# 1 Failed download:
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2008-01-01 -> 2024-08-25)')
#                              A      AAPL        ABT       ADBE        ADI  \
# Date
# 2008-01-02 00:00:00  23.293411  5.876339  18.215651  41.709999  20.164034
# 2008-01-03 00:00:00  23.062403  5.879056  18.104689  41.790001  19.858622
# 2008-01-04 00:00:00  22.311617  5.430277  18.209127  40.360001  19.340738
# 2008-01-07 00:00:00  22.677380  5.357593  18.767244  40.240002  19.095087
# 2008-01-08 00:00:00  22.645300  5.164869  19.260094  39.220001  18.464331
#
#                            ADM        ADP       ADSK        AEE        AEP  \
# Date
# 2008-01-02 00:00:00  29.735891  25.159904  48.240002  27.397566  23.718243
# 2008-01-03 00:00:00  30.044682  24.973621  47.840000  27.377045  23.789955
# 2008-01-04 00:00:00  30.123516  23.867558  45.700001  27.176762  23.713120
# 2008-01-07 00:00:00  30.130087  24.385670  46.720001  27.531096  24.404686
# 2008-01-08 00:00:00  29.578228  24.164459  44.820000  27.377045  24.389307
#
#                      ...         VZ        WBA        WFC         WM  \
# Date                 ...
# 2008-01-02 00:00:00  ...  17.285089  22.745798  18.486839  20.450424
# 2008-01-03 00:00:00  ...  17.365095  21.356928  18.118380  20.450424
# 2008-01-04 00:00:00  ...  17.041082  20.887878  17.464033  19.683374
# 2008-01-07 00:00:00  ...  17.341089  21.363016  17.584740  20.013012
# 2008-01-08 00:00:00  ...  16.965343  20.851320  16.835096  20.114435
#
#                            WMB        WMT         WY        XEL        XOM  \
# Date
# 2008-01-02 00:00:00  13.285971  10.909302  14.795911  12.195485  51.317204
# 2008-01-03 00:00:00  13.627587  10.788350  14.936590  12.266994  51.492825
# 2008-01-04 00:00:00  13.215417  10.634829  14.195969  12.129466  50.532433
# 2008-01-07 00:00:00  13.148576  10.830216  14.094602  12.316499  50.060474
# 2008-01-08 00:00:00  13.219129  10.692978  13.798759  12.189981  49.418400
#
#                            YUM
# Date
# 2008-01-02 00:00:00  19.597919
# 2008-01-03 00:00:00  19.323715
# 2008-01-04 00:00:00  19.049511
# 2008-01-07 00:00:00  19.494442
# 2008-01-08 00:00:00  18.997772
#
# [5 rows x 190 columns]

# %%
data = data.dropna(axis=1, how="all")
data.index = pd.to_datetime(data.index)
activos = data.columns

df_vixsi = pd.read_csv("../datos/VIXSIyf.csv", index_col=0)
df_vixsi.index =  pd.to_datetime(df_vixsi.index)
df_vixsi.columns=["vixsi"]
datos_vixsi = pd.concat([data[activos], df_vixsi.vixsi], axis=1).dropna()

# %% [markdown]
# ### alpha_vixsi_spy
#
# Una forma de validar la señal es ver cuanto alpha genera la estrategia que utiliza la señal para invertir en largo (vixsi=1) o en corto (vixsi=-1) utilizando como benchmar el propio activo SPY.
#
# la fórmula del alpha se basará en el alpha de Jensen (asignando 0 a la rentabilidad libre de riesgo):
#
# rentabilidad estrategia - Beta_estrategia_benchmark * rentabilidad benchmark
#
# El alpha se calculará por año, y se evaluará la media y el ratio de sharpe del alpha anual.
#
# Los datos del SPY se recogerán de yfinance y se ajustarán a los dividendos.

# %%
def f_alpha(datos, estrategia="estrategia", benchmark="SPY"):
    '''

    '''
    srets = np.log(datos[estrategia]).diff().fillna(0)
    brets = np.log(datos[benchmark]).diff().fillna(0)

    rent_srets = srets.sum()
    rent_brets = brets.sum()
    alpha = rent_srets - rent_brets    
    return (alpha, rent_srets, rent_brets)


def f_alpha_activo (datos, activo, fobj):

    estrategia = "estr"+activo
    datos[estrategia] = (1 + datos.vixsi.shift(1) * datos[activo].pct_change()).cumprod()
    años = sorted(datos.index.year.unique())
    alpha = np.zeros(len(años))
    benchmark = np.zeros(len(años))
    estrvixsi =  np.zeros(len(años))
    for i in range(len(años)):
        alpha[i], estrvixsi[i], benchmark[i] = f_alpha(datos.loc[str(años[i])],estrategia=estrategia, benchmark=activo)

    alpha = pd.DataFrame(alpha, index=años)
    benchmark = pd.DataFrame(benchmark, index=años)
    estrvixsi = pd.DataFrame(estrvixsi, index=años)
    #return (alpha, estrvixsi, benchmark, alpha.rolling(3).sum().dropna().min(), estrvixsi.rolling(3).sum().dropna().min())
    #return (alpha, estrvixsi, benchmark, alpha.rolling(3).sum().dropna().min(), alpha.rolling(3).sum().dropna().iloc[-1])
    if fobj==1:
        rend =  estrvixsi.rolling(3).sum().dropna().mean()
    elif fobj==2:
        rend =  estrvixsi.rolling(3).sum().dropna().iloc[-1]
    elif fobj==3:
        rend =  benchmark.rolling(3).sum().dropna().iloc[-1]
    else:
        rend =  benchmark.rolling(3).sum().dropna().iloc[-1]
    
    return (alpha, estrvixsi, benchmark, alpha.rolling(3).sum().dropna().min(), rend)

def f_estrategia_par (datos, activo, p_dwd1, p_dwd2, holding=False):

    if holding:
        return datos[activo].pct_change()

    max252 = datos["max"+activo]
    datos["dwd"] = (max252 - datos[activo])/max252*100
    datos["sigdwd1"] = (datos["dwd"] < p_dwd1) * 1
    datos["sigdwd2"] = (datos["dwd"] > p_dwd2) * 1
    rets_estrategia = (datos[activo].pct_change()
                       * datos.sigdwd1.shift(1) + 
     (1 - datos.sigdwd1.shift(1))*(1 - datos.sigdwd2.shift(1))*datos.vixsi.shift(1) * datos[activo].pct_change() +
     (1 - datos.sigdwd1.shift(1))*datos.sigdwd2.shift(1)*((datos.vixsi.shift(1) - 1)/2) * datos[activo].pct_change())
    return rets_estrategia


def f_opt_params (datos, activo, l_dwd1, l_dwd2):

    max_sharpe = -1000
    pm_dwd1 = 100
    pm_dwd2 = 0
    for p_dwd1 in l_dwd1:
        for p_dwd2 in l_dwd2:
            rets_estrategia = f_estrategia_par (datos, activo, p_dwd1, p_dwd2)
            estrategia = (1 + rets_estrategia).cumprod()
            _rets = np.log(estrategia).diff()
            _std = _rets.std()
            rsharpe = _rets.mean()/_std
            if rsharpe > max_sharpe:
                pm_dwd1 = p_dwd1
                pm_dwd2 = p_dwd2
                max_sharpe = rsharpe

    return pm_dwd1, pm_dwd2

def f_optimizar (datos, activos, activo_def = None, fobj=1):

    if activo_def == None:
        alpha_rend = np.zeros(len(activos))
        alpha_filtro = np.zeros(len(activos))
        for i,activo in enumerate(activos):
            alpha, estrvixsi, benchmark, filtro, rend = f_alpha_activo (datos, activo, fobj=fobj)
            alpha_filtro[i] = filtro
            alpha_rend[i] = rend

        alphas_df = pd.DataFrame(alpha_rend, index=activos)
        if fobj <= 2:
            activo = alphas_df[alpha_filtro > 0].sort_values(0, ascending=False).index[0]
        else:
            activo = alphas_df.sort_values(0, ascending=False).index[0]
    else:
        activo = activo_def

    lpar_dws1 = [-1,2,4,6]
    lpar_dws2 = [10,20,30,40,50]
    par_dwd1, par_dwd2 = f_opt_params (datos, activo, lpar_dws1, lpar_dws2)
    return activo, par_dwd1, par_dwd2

#seleccionar el primer día de cada año para hacer la optimización:
#se necesitan tres años como mínimo para la optimización

años = datos_vixsi.index.year.unique()
min_años = 3
#estrategia = pd.DataFrame(index=datos_vixsi.index)
df_estrategia = pd.DataFrame()
df_estrategia2 = pd.DataFrame()
df_estrategia3 = pd.DataFrame()
df_estrategia4 = pd.DataFrame()
df_holding = pd.DataFrame()
df_holding2 = pd.DataFrame()
df_holding3 = pd.DataFrame()
df_holding4 = pd.DataFrame()

for activo in activos:
    datos_vixsi["max"+activo] = datos_vixsi[activo].rolling(252).max()

for i in range(min_años,len(años)):
    datos_opt = datos_vixsi.loc[:str(años[i-1])]
    datos_test = datos_vixsi.loc[str(años[i])]
    #activo, par_dwd1, par_dwd2 = f_optimizar (datos_opt, activos, activo_def="KLAC")
    activo, par_dwd1, par_dwd2 = f_optimizar (datos_opt, activos, activo_def=None, fobj=1)
    print(años[i],len(datos_test),"activo:",activo,"par_dwd",par_dwd1,"par_dwd2",par_dwd2)
    activo2, par2_dwd1, par2_dwd2 = f_optimizar (datos_opt, activos, activo_def=None, fobj=2)
    print(años[i],len(datos_test),"activo2:",activo2,"par2_dwd",par_dwd1,"par2_dwd2",par_dwd2)
    activo3, par3_dwd1, par3_dwd2 = f_optimizar (datos_opt, activos, activo_def=None, fobj=3)
    print(años[i],len(datos_test),"activo3:",activo3,"par3_dwd",par_dwd1,"par3_dwd2",par_dwd2)
    activo4, par4_dwd1, par4_dwd2 = f_optimizar (datos_opt, activos, activo_def=None, fobj=4)
    print(años[i],len(datos_test),"activo4:",activo4,"par4_dwd",par_dwd1,"par4_dwd2",par_dwd2)
        
    rets_estrategia = f_estrategia_par (datos_test, activo, par_dwd1, par_dwd2)
    rets_estrategia2 = f_estrategia_par (datos_test, activo2, par2_dwd1, par2_dwd2)
    rets_estrategia3 = f_estrategia_par (datos_test, activo3, par3_dwd1, par3_dwd2)
    rets_estrategia4 = f_estrategia_par (datos_test, activo4, par4_dwd1, par4_dwd2)
    
    rets_holding = f_estrategia_par (datos_test, activo, par2_dwd1, par2_dwd2, holding=True)
    rets_holding2 = f_estrategia_par (datos_test, activo2, par2_dwd1, par2_dwd2, holding=True)
    rets_holding3 = f_estrategia_par (datos_test, activo3, par3_dwd1, par3_dwd2, holding=True)
    rets_holding4 = f_estrategia_par (datos_test, activo4, par4_dwd1, par4_dwd2, holding=True)
        
    df_estrategia = pd.concat([df_estrategia, pd.DataFrame(rets_estrategia, index=datos_test.index)], axis=0)
    df_estrategia2 = pd.concat([df_estrategia2, pd.DataFrame(rets_estrategia2, index=datos_test.index)], axis=0)
    df_estrategia3 = pd.concat([df_estrategia3, pd.DataFrame(rets_estrategia3, index=datos_test.index)], axis=0)
    df_estrategia4 = pd.concat([df_estrategia4, pd.DataFrame(rets_estrategia4, index=datos_test.index)], axis=0)
    
    
    holding  = pd.DataFrame(rets_holding, index=datos_test.index)
    holding.columns = ["benhcmark"]
    df_holding = pd.concat([df_holding, holding], axis=0)
    
    holding2  = pd.DataFrame(rets_holding2, index=datos_test.index)
    holding2.columns = ["benhcmark"]
    df_holding2 = pd.concat([df_holding2, holding2], axis=0)
    
    holding3  = pd.DataFrame(rets_holding3, index=datos_test.index)
    holding3.columns = ["benhcmark"]
    df_holding3 = pd.concat([df_holding3, holding3], axis=0)
    
    holding4  = pd.DataFrame(rets_holding4, index=datos_test.index)
    holding4.columns = ["benhcmark"]
    df_holding4 = pd.concat([df_holding4, holding4], axis=0)
# Out:
# 2011 252 activo: SCHW par_dwd -1 par_dwd2 50
# 2011 252 activo2: SCHW par2_dwd -1 par2_dwd2 50
# 2011 252 activo3: AZO par3_dwd -1 par3_dwd2 50
# 2011 252 activo4: AZO par4_dwd -1 par4_dwd2 50
# 2012 250 activo: SCHW par_dwd -1 par_dwd2 20
# 2012 250 activo2: BBWI par2_dwd -1 par2_dwd2 20
# 2012 250 activo3: BBWI par3_dwd -1 par3_dwd2 20
# 2012 250 activo4: BBWI par4_dwd -1 par4_dwd2 20
# 2013 252 activo: BBWI par_dwd 2 par_dwd2 50
# 2013 252 activo2: BBWI par2_dwd 2 par2_dwd2 50
# 2013 252 activo3: BBWI par3_dwd 2 par3_dwd2 50
# 2013 252 activo4: BBWI par4_dwd 2 par4_dwd2 50
# 2014 252 activo: BBWI par_dwd 2 par_dwd2 50
# 2014 252 activo2: CI par2_dwd 2 par2_dwd2 50
# 2014 252 activo3: PARA par3_dwd 2 par3_dwd2 50
# 2014 252 activo4: PARA par4_dwd 2 par4_dwd2 50
# 2015 252 activo: TJX par_dwd -1 par_dwd2 50
# 2015 252 activo2: CI par2_dwd -1 par2_dwd2 50
# 2015 252 activo3: LUV par3_dwd -1 par3_dwd2 50
# 2015 252 activo4: LUV par4_dwd -1 par4_dwd2 50
# 2016 252 activo: KLAC par_dwd -1 par_dwd2 50
# 2016 252 activo2: CI par2_dwd -1 par2_dwd2 50
# 2016 252 activo3: LUV par3_dwd -1 par3_dwd2 50
# 2016 252 activo4: LUV par4_dwd -1 par4_dwd2 50
# 2017 251 activo: CI par_dwd -1 par_dwd2 50
# 2017 251 activo2: MO par2_dwd -1 par2_dwd2 50
# 2017 251 activo3: LUV par3_dwd -1 par3_dwd2 50
# 2017 251 activo4: LUV par4_dwd -1 par4_dwd2 50
# 2018 251 activo: CI par_dwd -1 par_dwd2 50
# 2018 251 activo2: ADI par2_dwd -1 par2_dwd2 50
# 2018 251 activo3: BA par3_dwd -1 par3_dwd2 50
# 2018 251 activo4: BA par4_dwd -1 par4_dwd2 50
# 2019 252 activo: INTU par_dwd -1 par_dwd2 40
# 2019 252 activo2: INTU par2_dwd -1 par2_dwd2 40
# 2019 252 activo3: CSX par3_dwd -1 par3_dwd2 40
# 2019 252 activo4: CSX par4_dwd -1 par4_dwd2 40
# 2020 253 activo: KLAC par_dwd -1 par_dwd2 50
# 2020 253 activo2: KLAC par2_dwd -1 par2_dwd2 50
# 2020 253 activo3: ADBE par3_dwd -1 par3_dwd2 50
# 2020 253 activo4: ADBE par4_dwd -1 par4_dwd2 50
# 2021 252 activo: KLAC par_dwd -1 par_dwd2 50
# 2021 252 activo2: KLAC par2_dwd -1 par2_dwd2 50
# 2021 252 activo3: AAPL par3_dwd -1 par3_dwd2 50
# 2021 252 activo4: AAPL par4_dwd -1 par4_dwd2 50
# 2022 251 activo: KLAC par_dwd -1 par_dwd2 50
# 2022 251 activo2: KLAC par2_dwd -1 par2_dwd2 50
# 2022 251 activo3: KLAC par3_dwd -1 par3_dwd2 50
# 2022 251 activo4: KLAC par4_dwd -1 par4_dwd2 50
# 2023 250 activo: KLAC par_dwd -1 par_dwd2 50
# 2023 250 activo2: KLAC par2_dwd -1 par2_dwd2 50
# 2023 250 activo3: LLY par3_dwd -1 par3_dwd2 50
# 2023 250 activo4: LLY par4_dwd -1 par4_dwd2 50
# 2024 163 activo: KLAC par_dwd -1 par_dwd2 50
# 2024 163 activo2: KLAC par2_dwd -1 par2_dwd2 50
# 2024 163 activo3: MRO par3_dwd -1 par3_dwd2 50
# 2024 163 activo4: MRO par4_dwd -1 par4_dwd2 50

# %%
(1 + (df_estrategia + df_estrategia2)/2).cumprod().plot()
eq_estrategia_anual = (1 + (df_estrategia + df_estrategia2)/2).groupby(df_estrategia.index.year).prod()
eq_estrategia_anual
# Out:
#              0
# Date
# 2011  1.157290
# 2012  0.991411
# 2013  1.493852
# 2014  1.630020
# 2015  1.272231
# 2016  1.104890
# 2017  1.413592
# 2018  0.955565
# 2019  1.381022
# 2020  4.665607
# 2021  2.270119
# 2022  1.146796
# 2023  1.480640
# 2024  1.704950

# %%
(1 + (df_estrategia3 + df_estrategia4)/2).cumprod().plot()
eq2_estrategia_anual = (1 + (df_estrategia3 + df_estrategia4)/2).groupby(df_estrategia.index.year).prod()
eq2_estrategia_anual
# Out:
#              0
# Date
# 2011  1.164419
# 2012  1.126011
# 2013  1.493852
# 2014  1.022527
# 2015  0.953408
# 2016  0.911619
# 2017  1.099017
# 2018  1.060024
# 2019  1.448795
# 2020  3.167160
# 2021  1.356351
# 2022  1.146796
# 2023  1.826741
# 2024  1.049755

# %%
(1 + (df_holding + df_holding2)/2).cumprod().plot()

eq_holding_anual = (1 + (df_holding + df_holding2)/2).groupby(df_holding.index.year).prod()
eq_holding_anual
# Out:
#       benhcmark
# Date
# 2011   0.653804
# 2012   1.300239
# 2013   1.334093
# 2014   1.333990
# 2015   1.239439
# 2016   1.047657
# 2017   1.287978
# 2018   0.965336
# 2019   1.357549
# 2020   1.443766
# 2021   1.671306
# 2022   0.877851
# 2023   1.562483
# 2024   1.468313

# %%
(1 + (df_holding3 + df_holding4)/2).cumprod().plot()
eq2_holding_anual = (1 + (df_holding3 + df_holding4)/2).groupby(df_holding.index.year).prod()
eq2_holding_anual
# Out:
#       benhcmark
# Date
# 2011   1.210768
# 2012   1.330967
# 2013   1.334093
# 2014   0.882934
# 2015   1.015503
# 2016   1.198576
# 2017   1.320275
# 2018   1.107767
# 2019   1.184001
# 2020   1.495440
# 2021   1.380610
# 2022   0.877851
# 2023   1.612838
# 2024   1.165143

# %%
df_diff = pd.DataFrame((eq_estrategia_anual.values - eq_holding_anual.values), index=eq_estrategia_anual.index)
(1 + df_diff).cumprod().plot()
df_diff
# Out:
#              0
# Date
# 2011  0.503486
# 2012 -0.308828
# 2013  0.159759
# 2014  0.296030
# 2015  0.032792
# 2016  0.057233
# 2017  0.125615
# 2018 -0.009771
# 2019  0.023473
# 2020  3.221841
# 2021  0.598813
# 2022  0.268945
# 2023 -0.081843
# 2024  0.236637

# %%
df_diff2 = pd.DataFrame((eq_estrategia_anual.values - eq2_holding_anual.values), index=eq_estrategia_anual.index)
(1 + df_diff2).cumprod().plot()
df_diff2
# Out:
#              0
# Date
# 2011 -0.053478
# 2012 -0.339557
# 2013  0.159759
# 2014  0.747086
# 2015  0.256728
# 2016 -0.093685
# 2017  0.093317
# 2018 -0.152202
# 2019  0.197021
# 2020  3.170167
# 2021  0.889509
# 2022  0.268945
# 2023 -0.132198
# 2024  0.539808

# %%
columnas = ["estrvixsi","residual","spy"]
_plt = pd.concat([(1 + df_estrategia).cumprod(),(1 + (df_estrategia - df_spy)/2).cumprod(),(1 + df_spy).cumprod()], axis=1)
_plt.columns = columnas
_plt.plot()
df_diff_anual = pd.concat([(1 + df_estrategia).groupby(df_estrategia.index.year).prod(),
                           (1 + (df_estrategia - df_spy)/2).groupby(df_estrategia.index.year).prod(),
                     (1 + df_spy).groupby(df_estrategia.index.year).prod()], axis=1)
df_diff_anual.columns = columnas
print("promedios anuales:", df_diff_anual.mean().values)
df_diff_anual
# Out:
# promedios anuales: [1.63540179 1.18055064 1.14237594]
#       estrvixsi  residual       spy
# Date
# 2011   1.157290  1.088672  1.018950
# 2012   0.858745  0.866944  1.159903
# 2013   1.493852  1.081211  1.323078
# 2014   1.587922  1.181723  1.134638
# 2015   1.067400  1.028025  1.012343
# 2016   1.378600  1.103021  1.119979
# 2017   1.703727  1.190577  1.217054
# 2018   0.998955  1.030163  0.954310
# 2019   1.381022  1.031327  1.312239
# 2020   4.665607  2.055459  1.183316
# 2021   2.270119  1.348157  1.287288
# 2022   1.146796  1.214887  0.818246
# 2023   1.480640  1.095343  1.261758
# 2024   1.704950  1.212201  1.190162

# %%
print("promedios trianuales:", df_diff_anual.rolling(3).apply(lambda x: x.prod()).dropna().mean())
df_diff_anual.rolling(3).apply(lambda x: x.prod()).dropna()
# Out:
# promedios trianuales: estrvixsi    4.629471
# residual     1.713732
# spy          1.466743
# dtype: float64
#       estrvixsi  residual       spy
# Date
# 2013   1.484615  1.020466  1.563724
# 2014   2.037047  1.107687  1.741263
# 2015   2.532002  1.313499  1.519743
# 2016   2.336655  1.339995  1.286455
# 2017   2.507064  1.350034  1.379899
# 2018   2.346304  1.352843  1.300796
# 2019   2.350426  1.264911  1.524096
# 2020   6.436572  2.183793  1.481846
# 2021  14.627069  2.857890  1.998892
# 2022  12.146266  3.366548  1.246409
# 2023   3.854643  1.794015  1.329033
# 2024   2.894991  1.613097  1.228757
