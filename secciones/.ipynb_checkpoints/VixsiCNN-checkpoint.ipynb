# %%
# Los datasets de entrada son los deciles de FVIXSI y medias de 1 a 10 días,
# y el dataset de salida son los deciles de retsig con un
# modelo CNN sin optimizar
# El decil de salida se tiene que transormar a comprar, vender y a comprar, vender y mantener con una optimización
# 



import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings('ignore')

import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-darkgrid')

import yfinance as yf
from bs4 import BeautifulSoup
import requests
from datetime import datetime
from datetime import timedelta
from dateutil.relativedelta import relativedelta
import time
import pandas as pd
import numpy as np
import random
import time
from pathlib import Path

def cargar_datos (desde, hasta):
    '''
    
    '''

    spy_datos = yf.download("SPY", start=desde, end=hasta)
    vix_datos = yf.download("^VIX", start=desde, end=hasta)

    datos_all = pd.concat([spy_datos.Close, vix_datos.Close], axis=1).dropna()
    datos_all.columns = ["SPY","VIX"]
    datos_all["rets"] = datos_all.SPY.pct_change()

    # Indicadores para deltavix
    datos_all["FVIX"] = datos_all.VIX
    datos_all["FRETVIX"] = datos_all.VIX.pct_change()
    datos_all["FRET"] = datos_all.rets
    datos_all["FRVIX"] = np.abs(datos_all.rets) - datos_all.VIX/(np.sqrt(256)*100)
    datos_all["FVIXSI"] = datos_all.rets - datos_all.VIX/(np.sqrt(256)*100)
    #datos_all["vixsi"] = np.where(datos_all.rets - datos_all.VIX/(np.sqrt(256)*100) > 0, -1, 1)
    datos_all["vixsi"] = np.where(datos_all.rets - datos_all.VIX/(np.sqrt(256)*100) > 0, -1, 1)
    datos_all["pvixsi"] = np.where(datos_all.rets - datos_all.VIX/(np.sqrt(256)*100) > 0, 0, 1)
    datos_all["mvixsi"] = np.where(datos_all.VIX.pct_change(5) - (datos_all.VIX/(np.sqrt(256)*100)).rolling(5).mean() > 0, -1,1)
    datos_all["qretvix"] = datos_all.FRETVIX
    datos_all["qret"] = datos_all.FRET
    datos_all["qrvix"] = datos_all.FRVIX
    datos_all["qvix"] = datos_all.FVIX
    datos_all["retsig"] = datos_all.rets.shift(-1)

    datos_all.dropna(inplace=True)

    return datos_all

# %%
desde = "2008-01-01"
hasta = (datetime.now() + timedelta(1)).strftime("%Y-%m-%d")
hasta = "2024-11-20"
datos = cargar_datos (desde, hasta)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
(1 + datos.rets.shift(-1) * datos.vixsi).cumprod().plot()
(1 + datos.rets.shift(-1) * datos.pvixsi).cumprod().plot()
(1 + datos.rets.shift(-1)).cumprod().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
def designia_qt (datos_qt, datos, señales, periodos, result, numqt=10):
    
    if datos.index[-1] < datos_qt.index[-1]:
        return
    
    qdatos = []
    for j in range(len(señales)):
        qdatos.append(np.array(datos_qt[señales[j]].quantile([i / numqt for i in range(1, numqt+1)])))
        
    df_qdatos = pd.DataFrame(np.array(qdatos).T)
    df_qdatos.columns = señales
    
    qdatosY = np.array(datos_qt[result].quantile([i / numqt for i in range(1, numqt+1)]))
    fechas = []
    max_periodo = periodos[-1]
    numsig = len(señales)
    
    #dias, periodos, deciles, señal=[vixsi, retvix, vix]
    
    ldatos = []
    ldatosY = []
    for i in range(len(datos)-max_periodo):
        mdatos = np.zeros((len(periodos), numqt, numsig))
        mdatosY = np.zeros((numqt))
        for j in range(len(periodos)):
            datos_frec = datos.iloc[i+max_periodo-periodos[j]:i+max_periodo]
            for k in range(numqt):
                if k == 0:
                    for s in range(numsig):
                        mdatos[j, k, s] = len(datos_frec.loc[(datos_frec[df_qdatos.columns[s]] <= df_qdatos.iloc[k,s])])
                    #20241202
                    if periodos[j]==1:
                    #if j==len(periodos-1):                        
                        mdatosY[k] = len(datos_frec.loc[(datos_frec[result] < qdatosY[k])])
                else:
                    for s in range(numsig):
                        mdatos[j, k, s] = len(datos_frec.loc[(datos_frec[df_qdatos.columns[s]] > df_qdatos.iloc[k-1,s]) &
                                                      (datos_frec[df_qdatos.columns[s]] <= df_qdatos.iloc[k,s])])
                    if periodos[j]==1:
                        mdatosY[k] = len(datos_frec.loc[(datos_frec[result] <= qdatosY[k]) &
                                                          (datos_frec[result] > qdatosY[k-1])])
                if k == numqt-1:
                    for s in range(numsig):
                        mdatos[j, k, s] = (mdatos[j, k, s] +
                          len(datos_frec.loc[(datos_frec[df_qdatos.columns[s]] > df_qdatos.iloc[k,s])]))
                    #20241202
                    if periodos[j]==1:
                    #if j==len(periodos-1):
                        mdatosY[k] = mdatosY[k] + len(datos_frec.loc[(datos_frec[result] > qdatosY[k])])

            for s in range(len(df_qdatos.columns)):
                mdatos[j,:,s] = mdatos[j,:,s]/mdatos[j,:,s].sum()
            if periodos[j]==1:
                mdatosY = mdatosY/mdatosY.sum()

        ldatos.append(mdatos)
        ldatosY.append(mdatosY)
        fechas.append(datos.iloc[i+max_periodo-periodos[j]:i+max_periodo].index[-1])
            
    return np.array(ldatos), np.array(ldatosY), fechas

# %%
import pickle

ini = time.time()

periodos = [1, 5, 10, 20, 30, 40, 60, 90, 120, 240]
max_periodo = periodos[-1]
datos_train = datos.loc["2008-01-01":"2020-01-01"]
datos_qt = datos_train
datos_test = datos.loc[datos_train.index[-max_periodo]:]
X_train, Y_train, F_train = designia_qt (datos_qt, datos_train,
                                         señales=["FVIXSI"], periodos=periodos, result="retsig")
X_test, Y_test, F_test = designia_qt (datos_qt, datos_test, 
                                      señales=["FVIXSI"], periodos=periodos, result="retsig")

print ("tiempo creación datos train_test:", time.time()-ini)

with open('designia.pkl', 'wb') as file:
    pickle.dump((X_train, Y_train, F_train, X_test, Y_test, F_test), file)
# Out:
# tiempo creación datos train_test: 272.36138248443604

# %%
with open('designia.pkl', 'rb') as file:
    X_train, Y_train, F_train, X_test, Y_test, F_test = pickle.load(file)

# %%
canales = X_train.shape[3]

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, Flatten, Dense, MaxPooling2D

# Dimensiones de entrada y salida
input_shape = (10, 10, canales)  # Matriz de píxeles 10x10 con 3 canales (color)
num_classes = 10           # 10 clases de salida

# Crear el modelo de la red convolucional
model = Sequential([
    # Capa convolucional con 32 filtros, kernel de 3x3 y activación ReLU
    #Conv2D(32, (3, 3), padding="same", activation='relu', input_shape=input_shape),
    Conv2D(32, (3, 3), activation='relu', input_shape=input_shape),
    # Capa de pooling para reducir dimensiones
    MaxPooling2D(pool_size=(2, 2)),
    # Aplanar las características
    Flatten(),
    # Capa totalmente conectada con 64 neuronas y activación ReLU
    Dense(64, activation='relu'),
    # Capa de salida con activación softmax para clasificación en 10 clases
    Dense(num_classes, activation='softmax')
])

# Compilar el modelo
model.compile(
    optimizer='adam',                # Optimizador Adam
    loss='sparse_categorical_crossentropy',  # Pérdida para clasificación multiclase
    metrics=['accuracy']             # Métrica de precisión
)

# Resumen del modelo
model.summary()

Y_clases = np.argmax(Y_train, axis=1)
model.fit(X_train, Y_clases, epochs=20, batch_size=32, validation_split=0.2, verbose=1)
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 8, 8, 32)          320
#
#  max_pooling2d_7 (MaxPoolin  (None, 4, 4, 32)          0
#  g2D)
#
#  flatten_7 (Flatten)         (None, 512)               0
#
#  dense_14 (Dense)            (None, 64)                32832
#
#  dense_15 (Dense)            (None, 10)                650
#
# =================================================================
# Total params: 33802 (132.04 KB)
# Trainable params: 33802 (132.04 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Epoch 1/20
# 70/70 [==============================] - 1s 8ms/step - loss: 2.2821 - accuracy: 0.1299 - val_loss: 2.2562 - val_accuracy: 0.1508
# Epoch 2/20
# 70/70 [==============================] - 0s 5ms/step - loss: 2.2294 - accuracy: 0.1592 - val_loss: 2.2318 - val_accuracy: 0.1418
# Epoch 3/20
# 70/70 [==============================] - 0s 5ms/step - loss: 2.2042 - accuracy: 0.1727 - val_loss: 2.2228 - val_accuracy: 0.1257
# Epoch 4/20
# 70/70 [==============================] - 0s 6ms/step - loss: 2.1998 - accuracy: 0.1686 - val_loss: 2.2133 - val_accuracy: 0.1490
# Epoch 5/20
# 70/70 [==============================] - 0s 5ms/step - loss: 2.1890 - accuracy: 0.1682 - val_loss: 2.2152 - val_accuracy: 0.1436
# Epoch 6/20
# 70/70 [==============================] - 0s 6ms/step - loss: 2.1812 - accuracy: 0.1938 - val_loss: 2.2017 - val_accuracy: 0.1490
# Epoch 7/20
# 70/70 [==============================] - 0s 5ms/step - loss: 2.1724 - accuracy: 0.1879 - val_loss: 2.2126 - val_accuracy: 0.1293
# Epoch 8/20
# 70/70 [==============================] - 0s 6ms/step - loss: 2.1706 - accuracy: 0.1969 - val_loss: 2.2010 - val_accuracy: 0.1382
# Epoch 9/20
# 70/70 [==============================] - 0s 6ms/step - loss: 2.1647 - accuracy: 0.1947 - val_loss: 2.2031 - val_accuracy: 0.1544
# Epoch 10/20
# 70/70 [==============================] - 0s 4ms/step - loss: 2.1584 - accuracy: 0.2046 - val_loss: 2.2047 - val_accuracy: 0.1418
# Epoch 11/20
# 70/70 [==============================] - 0s 4ms/step - loss: 2.1516 - accuracy: 0.2001 - val_loss: 2.2005 - val_accuracy: 0.1472
# Epoch 12/20
# 70/70 [==============================] - 0s 4ms/step - loss: 2.1432 - accuracy: 0.2145 - val_loss: 2.2134 - val_accuracy: 0.1400
# Epoch 13/20
# 70/70 [==============================] - 0s 5ms/step - loss: 2.1356 - accuracy: 0.2113 - val_loss: 2.2004 - val_accuracy: 0.1454
# Epoch 14/20
# 70/70 [==============================] - 0s 6ms/step - loss: 2.1339 - accuracy: 0.2140 - val_loss: 2.2172 - val_accuracy: 0.1616
# Epoch 15/20
# 70/70 [==============================] - 0s 4ms/step - loss: 2.1236 - accuracy: 0.2167 - val_loss: 2.2113 - val_accuracy: 0.1580
# Epoch 16/20
# 70/70 [==============================] - 0s 5ms/step - loss: 2.1168 - accuracy: 0.2257 - val_loss: 2.2196 - val_accuracy: 0.1634
# Epoch 17/20
# 70/70 [==============================] - 0s 6ms/step - loss: 2.1103 - accuracy: 0.2284 - val_loss: 2.2058 - val_accuracy: 0.1472
# Epoch 18/20
# 70/70 [==============================] - 0s 5ms/step - loss: 2.1038 - accuracy: 0.2298 - val_loss: 2.2166 - val_accuracy: 0.1526
# Epoch 19/20
# 70/70 [==============================] - 0s 6ms/step - loss: 2.0968 - accuracy: 0.2307 - val_loss: 2.2279 - val_accuracy: 0.1346
# Epoch 20/20
# 70/70 [==============================] - 0s 5ms/step - loss: 2.0890 - accuracy: 0.2347 - val_loss: 2.2242 - val_accuracy: 0.1400

# %%
predict = model.predict(X_test)
df_predict = pd.DataFrame(predict, index=F_test)
df_predict["retsig"] = datos.loc[df_predict.index].retsig
df_predict["rets"] = datos.loc[df_predict.index].rets
df_predict["vixsi"] = datos.loc[df_predict.index].vixsi
df_predict["deltavix"] = df_predict.iloc[:,:-4].sum(axis=1)>0.9
#df_deltavix = df_predict[df_predict.iloc[:,:-3].sum(axis=1)>0.9]
#len(df_deltavix)/len(df_predict)
(1 + df_predict.retsig).cumprod().plot()
(1 + df_predict.retsig*df_predict.deltavix).cumprod().plot()
# Out:
# 39/39 [==============================] - 0s 3ms/step
# <Axes: >
